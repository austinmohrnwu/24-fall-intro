# %%
import matplotlib
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
import numpy as np
plots.style.use('fivethirtyeight')

# %% [markdown]
# # Lecture 25 #

# %% [markdown]
# ## Average (Mean) ##

# %%
values = make_array(2, 3, 3, 9)
values
# Out:
# array([2, 3, 3, 9], dtype=int64)

# %%
sum(values)/len(values)
# Out:
# 4.25

# %%
np.average(values)
# Out:
# 4.25

# %%
np.mean(values)
# Out:
# 4.25

# %%
# median
percentile(50, values)
# Out:
# 3

# %%
(2 + 3 + 3 + 9)/4
# Out:
# 4.25

# %%
2*(1/4) + 3*(2/4) + 9*(1/4)
# Out:
# 4.25

# %%
2*0.25 + 3*0.5 + 9*0.25
# Out:
# 4.25

# %%
values_table = Table().with_columns('value', values)
values_table
# Out:
# value
# 2
# 3
# 3
# 9

# %%
bins_for_display = np.arange(0.5, 10.6, 1)
values_table.hist('value', bins = bins_for_display)

plots.ylim(-0.04, 0.5)
plots.plot([0, 10], [0, 0], color='grey', lw=2)
plots.scatter(4.25, -0.015, marker='^', color='red', s=100)
plots.title('Average as a Center of Gravity');

# %%
symmetric = make_array(2, 3, 3, 4)
print(np.average(symmetric))
print(percentile(50, symmetric))
# Out:
# 3.0
# 3

# %%
bins_for_display = np.arange(0.5, 5.6, 1)
symmetric_table = Table().with_columns('value', symmetric)
symmetric_table.hist('value', bins = bins_for_display)

plots.ylim(-0.04, 0.75)
plots.plot([0, 6], [0, 0], color='grey', lw=2)
plots.scatter(np.mean(symmetric), -0.015, marker='^', color='red', s=100)
plots.title('Average as a Center of Gravity');

# %%
## Make array of 10 2s, 20 3s, and 10 9s

new_vals = make_array(2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
                      3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
                      9, 9, 9, 9, 9, 9, 9, 9, 9, 9)

# %%
Table().with_column('value', new_vals).hist(bins = bins_for_display)

# %%
np.average(new_vals)
# Out:
# 4.25

# %%
Table().with_column('value', new_vals).hist(bins = bins_for_display)
plots.ylim(-0.04, 0.5)
plots.plot([0, 10], [0, 0], color='grey', lw=2)
plots.scatter(4.25, -0.015, marker='^', color='red', s=100)
plots.title('Average as a Center of Gravity');

# %%
narrow = make_array(4,5,5,5,5,5,6)
wide = make_array(2, 3, 4, 5, 6, 7, 8)
print(np.average(narrow))
print(np.average(narrow))
# Out:
# 5.0
# 5.0

# %%
bins_for_display = np.arange(0.5, 9, 1)
narrow_table = Table().with_columns('value', narrow)
narrow_table.hist('value', bins = bins_for_display)

plots.ylim(-0.04, 0.75)
plots.plot([0, 9], [0, 0], color='grey', lw=2)
plots.scatter(np.mean(narrow), -0.015, marker='^', color='red', s=100)
plots.title('Average as a Center of Gravity');

# %%
bins_for_display = np.arange(0.5, 9, 1)
wide_table = Table().with_columns('value', wide)
wide_table.hist('value', bins = bins_for_display)

plots.ylim(-0.04, 0.75)
plots.plot([0, 9], [0, 0], color='grey', lw=2)
plots.scatter(np.mean(wide), -0.015, marker='^', color='red', s=100)
plots.title('Average as a Center of Gravity');

# %% [markdown]
# ## Standard Deviation ##

# %%
sd_table = Table().with_columns('Value', values)
sd_table
# Out:
# Value
# 100
# 135
# 115
# 125
# 93
# 178
# 140
# 125
# 136
# 120
# ... (1164 rows omitted)

# %%
sd_table.hist()

# %%
average_value = np.mean(values)
average_value
# Out:
# 128.4787052810903

# %%
deviations = values - average_value
sd_table = sd_table.with_column('Deviation', deviations)
sd_table
# Out:
# Value | Deviation
# 100   | -28.4787
# 135   | 6.52129
# 115   | -13.4787
# 125   | -3.47871
# 93    | -35.4787
# 178   | 49.5213
# 140   | 11.5213
# 125   | -3.47871
# 136   | 7.52129
# 120   | -8.47871
# ... (1164 rows omitted)

# %%
sum(deviations)
# Out:
# 1.7735146684572101e-11

# %%
sd_table = sd_table.with_column('Squared Deviation', deviations ** 2)
sd_table
# Out:
# Value | Deviation | Squared Deviation
# 100   | -28.4787  | 811.037
# 135   | 6.52129   | 42.5273
# 115   | -13.4787  | 181.675
# 125   | -3.47871  | 12.1014
# 93    | -35.4787  | 1258.74
# 178   | 49.5213   | 2452.36
# 140   | 11.5213   | 132.74
# 125   | -3.47871  | 12.1014
# 136   | 7.52129   | 56.5699
# 120   | -8.47871  | 71.8884
# ... (1164 rows omitted)

# %%
# Variance of the data:
# mean squared deviation from average

variance = np.mean(deviations ** 2)
variance
# Out:
# 429.54426544465696

# %%
# Standard Deviation (SD): 
# root mean squared deviation from average
# = square root of the variance

sd = variance ** 0.5
sd
# Out:
# 20.725449704280411

# %%
np.std(values)
# Out:
# 20.725449704280411

# %%
nba13 = Table.read_table('nba2013.csv')
nba13
# Out:
# Name            | Position | Height | Weight | Age in 2013
# DeQuan Jones    | Guard    | 80     | 221    | 23
# Darius Miller   | Guard    | 80     | 235    | 23
# Trevor Ariza    | Guard    | 80     | 210    | 28
# James Jones     | Guard    | 80     | 215    | 32
# Wesley Johnson  | Guard    | 79     | 215    | 26
# Klay Thompson   | Guard    | 79     | 205    | 23
# Thabo Sefolosha | Guard    | 79     | 215    | 29
# Chase Budinger  | Guard    | 79     | 218    | 25
# Kevin Martin    | Guard    | 79     | 185    | 30
# Evan Fournier   | Guard    | 79     | 206    | 20
# ... (495 rows omitted)

# %%
nba13.select('Height').hist(bins=np.arange(68, 88, 1))

# %%
mean_height = np.mean(nba13.column('Height'))
mean_height
# Out:
# 79.065346534653472

# %%
sd_height = np.std(nba13.column('Height'))
sd_height
# Out:
# 3.4505971830275546

# %%
nba13.sort('Height', descending=True).show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Position</th> <th>Height</th> <th>Weight</th> <th>Age in 2013</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Hasheem Thabeet</td> <td>Center  </td> <td>87    </td> <td>263   </td> <td>26         </td>
#         </tr>
#         <tr>
#             <td>Roy Hibbert    </td> <td>Center  </td> <td>86    </td> <td>278   </td> <td>26         </td>
#         </tr>
#         <tr>
#             <td>Alex Len       </td> <td>Center  </td> <td>85    </td> <td>255   </td> <td>20         </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (502 rows omitted)</p>

# %%
nba13.sort('Height').show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Position</th> <th>Height</th> <th>Weight</th> <th>Age in 2013</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Isaiah Thomas </td> <td>Guard   </td> <td>69    </td> <td>185   </td> <td>24         </td>
#         </tr>
#         <tr>
#             <td>Nate Robinson </td> <td>Guard   </td> <td>69    </td> <td>180   </td> <td>29         </td>
#         </tr>
#         <tr>
#             <td>John Lucas III</td> <td>Guard   </td> <td>71    </td> <td>157   </td> <td>30         </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (502 rows omitted)</p>

# %%
print((87 - mean_height)/sd_height)
print((69 - mean_height)/sd_height)
# Out:
# 2.29950151944
# -2.91698682888

# %% [markdown]
# ## Chebyshev's Bounds: "Tail" Bounds ##

# %%
# Proportion in the range "mean +/- 3.5 SDs"
# Chebyshev's bound: this proportion is AT LEAST
z = 3.5
1 - 1/z**2
# Out:
# 0.9183673469387755

# %%
# Proportion in the range "mean +/- 0.5 SDs"
# Chebyshev's bound: this proportion is AT LEAST
z = 0.5
1 - 1/z**2
# Out:
# -3.0

# %%
births = Table.read_table('baby.csv').drop('Maternal Smoker')

# %%
births.labels
# Out:
# ('Birth Weight',
#  'Gestational Days',
#  'Maternal Age',
#  'Maternal Height',
#  'Maternal Pregnancy Weight')

# %%
births.hist(overlay = False)

# %%
mpw = births.column('Maternal Pregnancy Weight')
mean = np.mean(mpw)
sd = np.std(mpw)
mean, sd
# Out:
# (128.4787052810903, 20.725449704280411)

# %%
within_3_SDs = births.where(
    'Maternal Pregnancy Weight', are.between(mean - 3*sd, mean + 3*sd))

# %%
# Proportion within 3 SDs of the mean

within_3_SDs.num_rows / births.num_rows
# Out:
# 0.9863713798977853

# %%
# Chebyshev's bound: 
# This proportion should be at least

1 - 1/3**2
# Out:
# 0.8888888888888888

# %%
births.labels
# Out:
# ('Birth Weight',
#  'Gestational Days',
#  'Maternal Age',
#  'Maternal Height',
#  'Maternal Pregnancy Weight')

# %%
# See if Chebyshev's bounds work for distributions with various shapes

for feature in births.labels:
    values = births.column(feature)
    mean = np.mean(values)
    sd = np.std(values)
    print()
    print(feature)
    for z in make_array(2, 3, 4, 5):
        chosen = births.where(feature, are.between(mean - z*sd, mean + z*sd))
        proportion = chosen.num_rows / births.num_rows
        percent = round(proportion * 100, 2)
        print('Average plus or minus', z, 'SDs:', percent, '%')
# Out:
# Birth Weight
# Average plus or minus 2 SDs: 94.89 %
# Average plus or minus 3 SDs: 99.57 %
# Average plus or minus 4 SDs: 100.0 %
# Average plus or minus 5 SDs: 100.0 %
#
# Gestational Days
# Average plus or minus 2 SDs: 93.78 %
# Average plus or minus 3 SDs: 98.64 %
# Average plus or minus 4 SDs: 99.57 %
# Average plus or minus 5 SDs: 99.83 %
#
# Maternal Age
# Average plus or minus 2 SDs: 94.89 %
# Average plus or minus 3 SDs: 99.91 %
# Average plus or minus 4 SDs: 100.0 %
# Average plus or minus 5 SDs: 100.0 %
#
# Maternal Height
# Average plus or minus 2 SDs: 97.19 %
# Average plus or minus 3 SDs: 99.66 %
# Average plus or minus 4 SDs: 99.91 %
# Average plus or minus 5 SDs: 100.0 %
#
# Maternal Pregnancy Weight
# Average plus or minus 2 SDs: 95.06 %
# Average plus or minus 3 SDs: 98.64 %
# Average plus or minus 4 SDs: 99.49 %
# Average plus or minus 5 SDs: 99.91 %

# %% [markdown]
# ## Standard Units ##

# %%
def standard_units(x):
    """Convert array x to standard units."""
    return (x - np.mean(x)) / np.std(x)

# %%
ages = births.column('Maternal Age')
ages
# Out:
# array([27, 33, 28, ..., 30, 21, 38])

# %%
ages_standard_units = standard_units(ages)
ages_standard_units
# Out:
# array([-0.03925456,  0.99249577,  0.13270383, ...,  0.47662061,
#        -1.07100488,  1.85228771])

# %%
np.mean(ages_standard_units), np.std(ages_standard_units)
# Out:
# (-7.868020072300939e-17, 1.0)

# %% [markdown]
# ## Discussion Question

# %%
both = Table().with_columns(
    'Age in Years', ages,
    'Age in Standard Units', ages_standard_units
)
both
# Out:
# Age in Years | Age in Standard Units
# 27           | -0.0392546
# 33           | 0.992496
# 28           | 0.132704
# 23           | -0.727088
# 25           | -0.383171
# 33           | 0.992496
# 23           | -0.727088
# 25           | -0.383171
# 30           | 0.476621
# 27           | -0.0392546
# ... (1164 rows omitted)

# %%
np.mean(ages), np.std(ages)
# Out:
# (27.228279386712096, 5.8153604041908968)

# %%
both.hist('Age in Years', bins = np.arange(15, 46, 2))

# %%
both.hist('Age in Standard Units', bins = np.arange(-2.2, 3.4, 0.35))
plots.xlim(-2, 3.1);

# %% [markdown]
# ## The SD and Bell Shaped Curves

# %%
births.hist('Maternal Height', bins = np.arange(56.5, 72.6, 1))
plots.xticks(np.arange(57, 72, 2));

# %% [markdown]
# Estimates by eye
#
# The average is approximately:
#
# Locate the point of inflection on the right. The SD is approximately:

# %%
heights = births.column('Maternal Height')
np.mean(heights), np.std(heights)
# Out:
# (64.049403747870528, 2.5250254409674375)
